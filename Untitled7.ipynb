# %%
import os
import numpy as np
import pandas as pd
import torch
from torch import nn, optim
from torch.utils.data import Dataset, DataLoader
from torchvision import models, transforms
from PIL import Image
import nltk
from collections import Counter
from nltk.translate.bleu_score import corpus_bleu
from nltk.tokenize import word_tokenize
import glob
from torchvision import transforms
from sklearn.model_selection import train_test_split

# %%
# pip install -r requirements.txt

# %%
# dataset_path = '/content/drive/MyDrive/flickr dataset'
dataset_path = "C:\\Users\\User\\\Documents\\FinalYearProject2025\\flickr dataset"

images_path = "C:\\Users\\User\\Documents\\FinalYearProject2025\\flickr dataset\\Images"
captions_path = "C:\\Users\\User\\Documents\\FinalYearProject2025\\flickr dataset\\captions.txt"

# %%
print(os.listdir(dataset_path))
# Out:
# ['captions.txt', 'Images']

# %%
print(images_path)
print(captions_path)
# Out:
# C:\Users\User\Documents\FinalYearProject2025\flickr dataset\Images
# C:\Users\User\Documents\FinalYearProject2025\flickr dataset\captions.txt

# %% [markdown]
# Load the pretrained model and do the image transformations

# %%
# Load pre-trained ResNet and remove the classification layer
resnet = models.resnet50(pretrained=True)
resnet = torch.nn.Sequential(*list(resnet.children())[:-1])
resnet.eval()  # Set to evaluation mode
print(resnet)
# Out:
# c:\Users\User\Documents\FinalYearProject2025\prac\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\User\Documents\FinalYearProject2025\prac\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to C:\Users\User/.cache\torch\hub\checkpoints\resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:22<00:00, 4.47MB/s]
# Sequential(
#   (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU(inplace=True)
#   (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (5): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (6): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (7): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (8): AdaptiveAvgPool2d(output_size=(1, 1))
# )

# %%
transform = transforms.Compose([
    transforms.Resize((224, 224)),  # Resize to match ResNet input size
    transforms.ToTensor(),          # Convert to tensor
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])  # Normalize
])

# %%
def extract_features(image_path, model, transform):
    image = Image.open(image_path).convert('RGB')  # Load and convert image to RGB
    image = transform(image).unsqueeze(0)  # Apply transformations and add batch dimension
    with torch.no_grad():  # Disable gradients for inference
        features = model(image).squeeze().numpy()  # Extract features
    return features

# %%
# Custom Dataset for Images
class ImageDataset(Dataset):
    def __init__(self, image_dir, transform):
        self.image_dir = image_dir
        self.image_files = [f for f in os.listdir(image_dir) if f.endswith(".jpg")]
        self.transform = transform

    def __len__(self):
        return len(self.image_files)

    def __getitem__(self, idx):
        image_file = self.image_files[idx]
        image_path = os.path.join(self.image_dir, image_file)
        image = Image.open(image_path).convert("RGB")
        image = self.transform(image)
        return image, image_file

# Initialize Dataset and DataLoader
image_dataset = ImageDataset(images_path, transform)
image_loader = DataLoader(image_dataset, batch_size=32, shuffle=False)

# Dictionary to store extracted features
image_features = {}

# Extract Features in Batches
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
resnet = resnet.to(device)  # Move ResNet model to GPU if available
resnet.eval()  # Set ResNet to evaluation mode

with torch.no_grad():  # Disable gradient calculation
    for batch_images, batch_image_files in image_loader:
        batch_images = batch_images.to(device)
        batch_features = resnet(batch_images)
        batch_features = batch_features.view(batch_features.size(0), -1).cpu().numpy()  # Flatten features

        # Store features in dictionary
        for img_file, feature in zip(batch_image_files, batch_features):
            image_features[img_file] = feature

print(f"Extracted features for {len(image_features)} images.")
# Out:
# Extracted features for 8091 images.

# %% [markdown]
# load captions

# %%
from tqdm import tqdm

def load_captions(captions_path):
    mapping = {}  # Initialize the mapping dictionary

    # Open the captions file and process each line
    
    with open(captions_path, 'r') as captions_file:
        captions_doc = captions_file.read()  # Read the entire content

        # Iterate over each line
        for line in tqdm(captions_doc.split('\n')):
            tokens = line.split(',')  # Split by comma

            # Skip lines that do not contain both image ID and caption
            if len(tokens) < 2:
                continue

            image_id, caption = tokens[0], tokens[1:]  # First token is image ID, rest are caption parts

            # Remove the file extension from the image ID
            image_id = image_id.split('.')[0]

            # Convert caption list into a single string
            caption = " ".join(caption)

            # If the image ID is not already in the mapping, create an empty list
            if image_id not in mapping:
                mapping[image_id] = []

            # Append the caption to the list of captions for the image
            mapping[image_id].append(caption)

    return mapping

# %%
captions_dict = load_captions(captions_path)
print(f"Number of captions loaded: {len(captions_dict)}")
# Out:
# 100%|██████████| 40457/40457 [00:00<00:00, 160595.25it/s]
# Number of captions loaded: 8092

# %%
# Strip the .jpg extension from image IDs in image_features
image_features = {img_id.split('.')[0]: features for img_id, features in image_features.items()}

# Verify the image IDs after stripping the extensions
print(f"First 5 image IDs in image_features after stripping: {list(image_features.keys())[:5]}")
# Out:
# First 5 image IDs in image_features after stripping: ['1000268201_693b08cb0e', '1001773457_577c3a7d70', '1002674143_1b742ab4b8', '1003163366_44323f5815', '1007129816_e794419615']

# %%
data_pairs = []

for img_id, captions in captions_dict.items():
    if img_id in image_features:  # Ensure matching keys
        for caption in captions:
            data_pairs.append((image_features[img_id], caption))

print(f"Number of data pairs: {len(data_pairs)}")
# Out:
# Number of data pairs: 40455

# %% [markdown]
# tokenize captions

# %%
from collections import Counter
import nltk
nltk.download('punkt_tab')

class Vocabulary:
    def __init__(self):
        self.word2idx = {}
        self.idx2word = {}
        self.idx = 0

    def add_word(self, word):
        if word not in self.word2idx:
            self.word2idx[word] = self.idx
            self.idx2word[self.idx] = word
            self.idx += 1

    def build_vocab(self, captions, freq_threshold=5):
        # Count word frequencies
        counter = Counter()
        for caption in captions:
            tokens = nltk.word_tokenize(caption.lower())
            counter.update(tokens)

        # Add words above frequency threshold to the vocabulary
        for word, freq in counter.items():
            if freq >= freq_threshold:
                self.add_word(word)

    def numericalize(self, caption):
        # Convert caption into a list of indices
        tokens = nltk.word_tokenize(caption.lower())
        return [self.word2idx.get(token, self.word2idx['<unk>']) for token in tokens]

# Build vocabulary
all_captions = [caption for captions in captions_dict.values() for caption in captions]

vocab = Vocabulary()
vocab.add_word('<pad>')  # Padding token
vocab.add_word('<start>')  # Start token
vocab.add_word('<end>')  # End token
vocab.add_word('<unk>')  # Unknown token
vocab.build_vocab(all_captions, freq_threshold=5)
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.

# %% [markdown]
# data loader

# %%
import torch
from torch.utils.data import Dataset, DataLoader
from torch.nn.utils.rnn import pad_sequence

# Custom collate function for padding captions
def collate_fn(batch):
    image_features, captions = zip(*batch)

    # Pad the captions to the same length
    padded_captions = pad_sequence(captions, batch_first=True, padding_value=0)  # 0 is the <pad> token

    # Stack image features into a single tensor
    image_features = torch.stack(image_features, 0)

    return image_features, padded_captions


# Dataset class
class ImageCaptionDataset(Dataset):
    def __init__(self, image_features, captions_dict, vocab):
        self.image_features = image_features
        self.captions = []
        self.vocab = vocab

        # Pair image features with tokenized captions
        for img_id, captions in captions_dict.items():
            if img_id in image_features:
                for caption in captions:
                    self.captions.append((image_features[img_id], caption))

    def __len__(self):
        return len(self.captions)

    def __getitem__(self, idx):
        image_feature, caption = self.captions[idx]
        # Add start and end tokens, then numericalize
        tokens = [self.vocab.word2idx['<start>']] + \
                 self.vocab.numericalize(caption) + \
                 [self.vocab.word2idx['<end>']]
        return torch.tensor(image_feature), torch.tensor(tokens)


# Initialize dataset (use your `image_features` and `captions_dict`)
dataset = ImageCaptionDataset(image_features, captions_dict, vocab)

# Create DataLoader with custom collate function
dataloader = DataLoader(dataset, batch_size=32, shuffle=True, collate_fn=collate_fn)

# %% [markdown]
# encoder decoder model
# Encoder: Maps image features to embeddings.
# Decoder: Generates captions using an LSTM.

# %%
import torch.nn as nn

class EncoderDecoderModel(nn.Module):
    def __init__(self, feature_dim, embed_dim, hidden_dim, vocab_size):
        super(EncoderDecoderModel, self).__init__()
        # Encoder (fully connected layer to map image features)
        self.encoder = nn.Linear(feature_dim, embed_dim)

        # Decoder
        self.embedding = nn.Embedding(vocab_size, embed_dim)
        self.lstm = nn.LSTM(embed_dim, hidden_dim, batch_first=True)
        self.fc_out = nn.Linear(hidden_dim, vocab_size)

    def forward(self, image_features, captions):
        # Encode image features
        image_embeddings = self.encoder(image_features)

        # Embed captions
        captions_embeddings = self.embedding(captions)

        # Concatenate image embeddings and caption embeddings
        embeddings = torch.cat((image_embeddings.unsqueeze(1), captions_embeddings), dim=1)

        # Pass through LSTM
        lstm_out, _ = self.lstm(embeddings)

        # Predict the next word
        outputs = self.fc_out(lstm_out)
        return outputs

# %%
feature_dim = 2048  # From ResNet-50
embed_dim = 256
hidden_dim = 512
vocab_size = len(vocab.word2idx)

model = EncoderDecoderModel(feature_dim, embed_dim, hidden_dim, vocab_size)

# %% [markdown]
# training the model

# %%
criterion = nn.CrossEntropyLoss(ignore_index=vocab.word2idx['<pad>'])  # Ignore padding tokens
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %%
epochs = 15

for epoch in range(epochs):
    model.train()  # Set model to training mode
    epoch_loss = 0

    for image_features, captions in dataloader:
        optimizer.zero_grad()  # Reset gradients

        # Shift the captions for input/output
        inputs = captions[:, :-1]  # All tokens except the last one
        targets = captions[:, 1:]  # All tokens except the first one

        # Append padding token to the targets to make its length same as the output sequence
        padding_token = 0  # Adjust this to the appropriate padding index if necessary
        padded_targets = torch.cat((targets, torch.full((targets.size(0), 1), padding_token, dtype=targets.dtype)), dim=1)

        # Forward pass
        outputs = model(image_features, inputs)

        # Flatten outputs and targets for loss calculation
        outputs = outputs.reshape(-1, vocab_size)  # Flattened outputs
        targets = padded_targets.reshape(-1)  # Flattened padded targets

        # Ensure outputs and targets have the same number of elements
        assert outputs.size(0) == targets.size(0), f"Output size {outputs.size(0)} does not match target size {targets.size(0)}"

        # Calculate loss
        loss = criterion(outputs, targets)
        epoch_loss += loss.item()

        # Backward pass and update weights
        loss.backward()
        optimizer.step()

    print(f"Epoch [{epoch + 1}/{epochs}], Loss: {epoch_loss / len(dataloader):.4f}")
# Out:
# Epoch [1/15], Loss: 4.0279
# Epoch [2/15], Loss: 3.5135
# Epoch [3/15], Loss: 3.2606
# Epoch [4/15], Loss: 3.0710
# Epoch [5/15], Loss: 2.8977
# Epoch [6/15], Loss: 2.7350
# Epoch [7/15], Loss: 2.5840
# Epoch [8/15], Loss: 2.4397
# Epoch [9/15], Loss: 2.3094
# Epoch [10/15], Loss: 2.1930
# Epoch [11/15], Loss: 2.0866
# Epoch [12/15], Loss: 1.9889
# Epoch [13/15], Loss: 1.9061
# Epoch [14/15], Loss: 1.8281
# Epoch [15/15], Loss: 1.7639

# %%
# Save the trained model
torch.save(model.state_dict(), "image_captioning_model.pth")
print("Model saved successfully.")
# Out:
# Model saved successfully.

# %%
# Load the saved model
model.load_state_dict(torch.load("image_captioning_model.pth"))
model.eval()  # Set model to evaluation mode
print("Model loaded successfully.")
# Out:
# Model loaded successfully.
# C:\Users\User\AppData\Local\Temp\ipykernel_3388\2386410587.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load("image_captioning_model.pth"))

# %%
import shutil
from sklearn.model_selection import train_test_split

# Paths
source_folder = r"C:\\Users\\User\\Documents\\FinalYearProject2025\\flickr dataset\\Images"
train_folder = r"C:\\Users\\User\\Documents\\FinalYearProject2025\\flickr dataset\\Train"
val_folder = r"C:\\Users\\User\\Documents\\FinalYearProject2025\\flickr dataset\\Validation"
test_folder = r"C:\\Users\\User\\Documents\\FinalYearProject2025\\flickr dataset\\Test"

# Create directories if they don't exist
os.makedirs(train_folder, exist_ok=True)
os.makedirs(val_folder, exist_ok=True)
os.makedirs(test_folder, exist_ok=True)

# Get all images from the source folder
all_images = [f for f in os.listdir(source_folder) if f.endswith('.jpg')]

if not all_images:
    raise ValueError("No .jpg files found in the source folder.")

# Split into train + validation and test sets
train_val_images, test_images = train_test_split(all_images, test_size=0.2, random_state=42)
print(f"Train+Validation images: {len(train_val_images)}, Test images: {len(test_images)}")

# Split train+validation set into train and validation subsets
train_images, val_images = train_test_split(train_val_images, test_size=0.25, random_state=42)
# 0.25 * 80% = 20%, so train: 60%, validation: 20%, test: 20%

print(f"Train images: {len(train_images)}, Validation images: {len(val_images)}, Test images: {len(test_images)}")

# Copy train images
for image in train_images:
    shutil.copy(os.path.join(source_folder, image), os.path.join(train_folder, image))

# Copy validation images
for image in val_images:
    shutil.copy(os.path.join(source_folder, image), os.path.join(val_folder, image))

# Copy test images
for image in test_images:
    shutil.copy(os.path.join(source_folder, image), os.path.join(test_folder, image))

print("Dataset successfully divided into Train, Validation, and Test sets!")
# Out:
# Train+Validation images: 6472, Test images: 1619
# Train images: 4854, Validation images: 1618, Test images: 1619
# Dataset successfully divided into Train, Validation, and Test sets!

# %%
import glob
from torchvision import models, transforms
import torch
from PIL import Image

# Step 1: Define the device (CPU/GPU)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Step 2: Initialize ResNet as the feature extractor
# Use a pre-trained ResNet model (e.g., ResNet50)
resnet = models.resnet50(pretrained=True)
# Remove the fully connected (fc) layer
feature_extractor = torch.nn.Sequential(*list(resnet.children())[:-1])
feature_extractor = feature_extractor.to(device)
feature_extractor.eval()  # Set to evaluation mode

# Step 3: Transform for test images
test_transform = transforms.Compose([
    transforms.Resize((224, 224)),  # Resize image to 224x224
    transforms.ToTensor(),  # Convert image to tensor
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])  # Normalize with ImageNet mean and std
])

# Step 4: Get all .jpg files in the directory
#test_images_path = "C:\\Users\\User\\Documents\\FinalYearProject2025\\flickr dataset\\test\\*.jpg"C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test
test_image_paths = glob.glob(test_images_path)  # List all .jpg files in the directory

# Step 5: Iterate over each image and extract features
for test_image_path in test_image_paths:
    print(f"Processing image: {test_image_path}")
    
    # Load and preprocess each test image
    image = Image.open(test_image_path).convert('RGB')  # Convert image to RGB
    image_tensor = test_transform(image).unsqueeze(0).to(device)  # Add batch dimension and send to device

    # Step 6: Extract features using ResNet (or your feature extractor)
    with torch.no_grad():  # Disable gradient computation for inference
        image_features = feature_extractor(image_tensor)  # Extract features
        image_features = image_features.squeeze().unsqueeze(0)  # Remove unnecessary dimensions

    # You can process or store the features here for each image
    print("Extracted Image Features Shape:", image_features.shape)
# Out:
# c:\Users\User\Documents\FinalYearProject2025\prac\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\User\Documents\FinalYearProject2025\prac\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1022454428_b6b660a67b.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\102351840_323e3de834.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1028205764_7e8df9a2ea.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\103195344_5d2dc613a3.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\104136873_5b5d41be75.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1042590306_95dea0916c.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\105342180_4d4a40b47f.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1056249424_ef2a2e041c.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\106490881_5a2dd9b7bd.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1067180831_a59dc64344.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\107582366_d86f2d3347.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1075867198_27ca2e7efe.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1075881101_d55c46bece.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1079274291_9aaf896cc1.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1084040636_97d9633581.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1088767354_2acee738cf.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1089755335_0bfbfd30e6.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1093737381_b313cd49ff.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1094462889_f9966dafa6.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1095980313_3c94799968.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1096395242_fc69f0ae5a.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\109671650_f7bbc297fa.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\109823394_83fcb735e1.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\109823397_e35154645f.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1104133405_c04a00707f.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1105959054_9c3a738096.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1110208841_5bb6806afe.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1112212364_0c48235fc2.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1115679311_245eff2f4b.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1129704496_4a61441f2c.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1141718391_24164bf1b1.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1141739219_2c47195e4c.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\116409198_0fe0c94f3b.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1174525839_7c1e6cfa86.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1174629344_a2e1a2bdbf.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1191338263_a4fa073154.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1193116658_c0161c35b5.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\119534510_d52b3781a3.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1204996216_71d7519d9a.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1213336750_2269b51397.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1215334959_b1970965f7.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\121971540_0a986ee176.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1222322358_225067636e.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1229756013_94663527d7.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1240297429_c36ae0c58f.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\124195430_d14028660f.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1248940539_46d33ed487.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1255504166_f2437febcb.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1262454669_f1caafec2d.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1271210445_7f7ecf3791.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1273001772_1585562051.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\127490019_7c5c08cb11.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\12830823_87d2654e31.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1287475186_2dee85f1a5.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1287931016_fb015e2e10.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1287982439_6578006e22.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1289142574_2bd6a082dd.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\129599450_cab4e77343.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1299459562_ed0e064aee.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1313961775_824b87d155.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1322323208_c7ecb742c6.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1329832826_432538d331.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1338523142_57fce8229b.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1346051107_9cdc14e070.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1347519824_e402241e4f.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1348113612_5bfc5f429e.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1348891916_ebd4413033.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1348947380_14f0fc1237.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1348957576_c4a78eb974.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1351764581_4d4fb1b40f.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1354318519_2f9baed754.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1355703632_5683a4b6fb.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1361420539_e9599c60ae.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1363924449_487f0733df.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\136639119_6040b00946.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\136644885_f7d2bbf546.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1368338041_6b4077ca98.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\138705546_be7a6845dd.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1390268323_2c8204e91c.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1394396709_65040d97ab.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1400424834_1c76e700c4.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1402843760_d30f1dbf0f.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\140430106_2978fda105.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1410193619_13fff6c875.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1414820925_3504c394e1.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\141755290_4b954529f3.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1418503947_953d373632.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1420060118_aed262d606.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1425069308_488e5fcf9d.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1425485485_d7c97a5470.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1429546659_44cb09cbe2.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1429814475_0b592b9995.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1433142189_cda8652603.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1434607942_da5432c28c.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\143688283_a96ded20f1.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1439282131_3814d6ae04.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1440024115_129212c988.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1445754124_647168f211.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1446053356_a924b4893f.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1449370354_380c4123c9.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1449692616_60507875fb.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1456393634_74022d9056.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\145721498_a27d2db576.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1457762320_7fe121b285.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1460500597_866fa0c6f3.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1461667284_041c8a2475.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1464120327_d90279ca3a.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\146577646_9e64b8c2dc.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1468389504_c724bdcad0.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1468962616_5803b4397f.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1472230829_803818a383.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1478294229_7e1c822fea.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1479028910_3dab3448c8.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1479124077_17dcc0d5d7.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1479513774_70c94cf9d3.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1479679558_d0a01bc62b.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1481062342_d9e34366c4.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\148512773_bae6901fd6.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1490213660_9ea45550cf.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1490670858_e122df2560.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1499554025_a8ffe0e479.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1499581619_a5f65a882c.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1500853305_0150615ce9.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1501297480_8db52c15b0.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1505686764_9e3bcd854a.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1511807116_41c3645e8c.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1523984678_edd68464da.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1526325728_74eb4153d8.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1540631615_8b42c1b160.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1541272333_1624b22546.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\155221027_b23a4331b7.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1564614124_0ee6799935.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1574401950_6bedc0d29b.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1584315962_5b0b45d02d.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1597557856_30640e0b43.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1598085252_f3219b6140.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1600208439_e94527b80f.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\162743064_bb242faa31.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1643915227_9f48068772.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1659396176_ced00a549f.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1682079482_9a72fa57fa.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\171488318_fb26af58e2.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\172097782_f0844ec317.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\172097783_292c5413d8.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1721637099_93e9ec2a2f.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1764955991_5e53a28c87.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1765164972_92dac06fa9.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1771490732_0ab5f029ac.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1776981714_5b224d0f7a.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1785138090_76a56aaabc.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1794818900_e0ffdd268e.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1795151944_d69b82f942.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1797507760_384744fb34.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1807169176_7f5226bf5a.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1808504612_3508f3c9bb.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1809758121_96026913bb.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1810651611_35aae644fb.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\181103691_fb2f956abd.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1813777902_07d1d4b00c.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1814086703_33390d5fc7.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1818403842_553a2a392c.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1819261140_6c022f4b1d.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1835511273_790eaae6e6.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1858963639_4588cd4be9.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\186346360_541047336f.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1865794069_6e3a1e57bb.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\186890601_8a6b0f1769.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\189721896_1ffe76d89e.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\19212715_20476497a3.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1924234308_c9ddcf206d.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1932161768_996eadac87.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1937262236_cbf5bfa101.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\195084264_72fb347b0f.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\197142902_f05ff198c2.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\1999444757_1b92efb590.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2009636597_e3f4fe19fb.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2017276266_566656c59d.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2034553054_b00c166895.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2041867793_552819a40b.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2045023435_181854c013.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2046222127_a6f300e202.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2049051050_20359a434a.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2053006423_6adf69ca67.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2053441349_a98b5fc742.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2057160636_6e9cf3b5f0.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2057306459_2f52ce648e.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2058124718_89822bc96e.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2063277300_f7ff476914.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2069279767_fb32bfb2de.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2076428547_738e0a132f.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2077346067_0a3a5aae65.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2079554580_f18d5c181b.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2081446176_f97dc76951.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2086534745_1e4ab80078.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2087640654_1a84577a44.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2089122314_40d5739aef.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2089542487_b4c1ee7025.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2092870249_90e3f1855b.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2097403787_77a154f5b9.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2097420505_439f63c863.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2097489021_ca1b9f5c3b.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2100046085_69b59b6645.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2100909581_b7dde5b704.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2101808682_0d66ef4a08.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2102030040_2e8f4738f7.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2103568100_5d018c495b.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2105756457_a100d8434e.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2106772874_381824648b.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2107837987_ffecfc367a.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\210839948_bbd5bfa3b6.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2108799322_e25aa6e185.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2109479807_eec8d72ca7.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\211277478_7d43aaee09.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2112921744_92bf706805.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2114355355_9d7e2d8178.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2115631346_9585a479b0.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2115849046_2aa9fa8d13.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2116444946_1f5d1fe5d1.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2119660490_ce0d4d1f73.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\211981411_e88b8043c2.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2121357310_f8235311da.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2124040721_bffc0a091a.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2125216241_5b265a2fbc.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2125454445_5c5c4bf906.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2127207912_9298824e66.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2136514643_93d8f75a77.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2136992638_098d62a3c5.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2138487671_5b89104043.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2141713971_e25eb12712.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2144050118_3e7d2e05b1.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2149982207_5345633bbf.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2156726763_034ecd2e39.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2170222061_e8bce4a32d.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2172493537_128bc8b187.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2172526745_649f420569.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2173061319_1f267765dc.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2180356743_b3a3c9a7f6.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2180886307_5156460b2c.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2181724497_dbb7fcb0a9.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2182488373_df73c7cc09.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2185793891_5a5e903ca6.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2189181027_a445b13438.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2191329761_3effd856c5.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2192333873_2a0cbe849d.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2192475933_d779bf42eb.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2192802444_b14bb87b95.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\219301553_d2fffe9e0c.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2194286203_5dc620006a.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2194494220_bb2178832c.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2194797921_96af7a9467.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2196050115_e236d91f52.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2197275664_fabcf3424b.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2198484810_50a893824a.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2198511848_311d8a8c2f.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2199250692_a16b0c2ae1.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2204695848_3d1b140212.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2206594874_5e0087c6b7.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2206960564_325ed0c7ae.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2217728745_92b6779016.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2218519240_cac5aab53c.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2220175999_081aa9cce8.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2222559267_6fd31e3941.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\222369445_5b6af347dd.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2224995194_518859d97d.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2230067846_74046b89d3.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\223299142_521aedf9e7.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2238166082_140f8b01b8.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2242863004_3a9f82a31f.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2243904502_2d265fed80.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2245348304_08bc5642f1.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2248487950_c62d0c81a9.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2249141510_f534708374.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2250870111_8402d2319d.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2251418114_2b0cd4c139.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2251447809_2de73afcdf.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2251747182_6b67a3ab8b.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2252403744_148fc11f68.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2254913901_569f568926.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2255685792_f70474c6db.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2256231539_05c27179f1.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2257798999_d9d1b9a45a.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2258662398_2797d0eca8.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2260560631_09093be4c6.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2267682214_e1434d853b.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2268109835_d6edbe1c2b.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2268115375_69884e958d.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2268596214_ca532f5c63.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2271468944_3264d29208.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2271671533_7538ccd556.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\2273799395_5072a5736d.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# ...
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\539705321_99406e5820.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\539761097_5c6c70425b.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\540604040_bec822c144.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\540721368_12ac732c6c.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\540873795_ae62ae6f60.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\541046380_513e295384.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\544301311_5e7d69a517.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\544576742_283b65fa0d.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\551403320_dfdcf9fc3b.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\554774472_b5d165ff69.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\557101732_32bbc47c12.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\557721978_dfde31bc02.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\562588230_edb2c071c8.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\566384456_97da3c7bd6.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\57422853_b5f6366081.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\576075451_5e0f6facb3.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\581419370_30485f3580.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\582788646_dc40748639.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\599366440_a238e805cf.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\608257195_6ec6f48e37.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\609681901_66809d2dc1.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\61209225_8512e1dad5.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\616177206_0e16c33f6b.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\617038406_4092ee91dd.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\632608471_a70461f123.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\640506101_ae1145b6d1.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\642987597_03b21a1437.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\652542470_60e858da64.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\654130822_4aeb1f1273.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\661755629_602ea4cf09.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\661757041_61e131e913.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\662606040_8cc8cd9f1b.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\684255145_db3f8e3e46.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\689776124_07f560a920.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\691770760_48ce80a674.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\693450725_8ad72389e6.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\697582336_601462e052.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\697778778_b52090709d.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\700884207_d3ec546494.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\707972553_36816e53a2.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\709373049_15b8b6457a.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\710878348_323082babd.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\72218201_e0e9c7d65b.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\724702877_f2a938766b.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\733172023_5810350af6.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\733752482_ee01a419e5.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\742073622_1206be8f7f.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\745966757_6d16dfad8f.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\747242766_afdc9cb2ba.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\750196276_c3258c6f1b.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\756004341_1a816df714.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\756521713_5d3da56a54.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\757133580_ba974ef649.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\757332692_6866ae545c.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\760138567_762d9022d4.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\769260947_02bc973d76.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\781118358_19087c9ec0.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\781387473_208ba152b3.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\783353797_fdf91bdf4c.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\795081510_53fd17d101.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\799486353_f665d7b0f0.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\811662356_f9a632b63c.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\823675317_b5fbdb17b3.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\824923476_d85edce294.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\836828001_af98d16256.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\842960985_91daf0d6ec.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\848293676_98e73c52c1.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\854333409_38bc1da9dc.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\857914283_270d7d1c87.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\862054277_34b5a6f401.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\864290968_eccb46d5ab.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\866841633_05d273b96d.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\874665322_9ad05c4065.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\881725588_efabbcd96a.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\883040210_3c4a10f030.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\887108308_2da97f15ef.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\90011335_cfdf9674c2.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\905355838_3a43fdfd4e.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\917574521_74fab68514.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\929679367_ff8c7df2ee.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\930126921_1b94605bdc.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\937559727_ae2613cee5.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\94232465_a135df2711.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\942399470_6132d3e5d2.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\944788251_a0bcd4b960.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\946051430_8db7e4ce09.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\95728660_d47de66544.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\957682378_46c3b07bcd.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\96985174_31d4c6f06d.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\970641406_9a20ee636a.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\972381743_5677b420ab.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\977856234_0d9caee7b2.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\978580450_e862715aba.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\979383193_0a542a059d.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\985067019_705fe4a4cc.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\989754491_7e53fb4586.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\997338199_7343367d7f.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])
# Processing image: C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test\997722733_0cb5439472.jpg
# Extracted Image Features Shape: torch.Size([1, 2048])

# %%
print(captions_path)
# Out:
# C:\Users\User\Documents\FinalYearProject2025\flickr dataset\captions.txt

# %%
print(f"Number of reference captions: {len(reference_captions)}")
print(f"Sample reference captions: {list(reference_captions.items())[:5]}")
# Out:
# Number of reference captions: 0
# Sample reference captions: []

# %%
def load_captions(file_path):
    captions_dict = {}
    with open(file_path, 'r') as f:
        for line in f:
            # Split by comma instead of tab
            parts = line.strip().split(',')
            if len(parts) < 2:
                image_id, caption = parts
                image_id = image_id.split("#")[0]  # Extract image name without #index
                if image_id not in captions_dict:
                    captions_dict[image_id] = []
                # Tokenize and add as a list of words
                captions_dict[image_id].append(word_tokenize(caption.lower()))
            else:
                print(f"Skipping invalid line: {line.strip()}")
    return captions_dict

# %%
# Print a few reference captions to inspect the format
for image_id, captions in list(reference_captions.items())[:5]:  # Print first 5 items
    print(f"Image ID: {image_id}")
    print(f"Captions: {captions}")
# Out:
# Image ID: image
# Captions: [['caption']]
# Image ID: 1000268201_693b08cb0e.jpg
# Captions: [['a', 'child', 'in', 'a', 'pink', 'dress', 'is', 'climbing', 'up', 'a', 'set', 'of', 'stairs', 'in', 'an', 'entry', 'way', '.'], ['a', 'girl', 'going', 'into', 'a', 'wooden', 'building', '.'], ['a', 'little', 'girl', 'climbing', 'into', 'a', 'wooden', 'playhouse', '.'], ['a', 'little', 'girl', 'climbing', 'the', 'stairs', 'to', 'her', 'playhouse', '.'], ['a', 'little', 'girl', 'in', 'a', 'pink', 'dress', 'going', 'into', 'a', 'wooden', 'cabin', '.']]
# Image ID: 1001773457_577c3a7d70.jpg
# Captions: [['a', 'black', 'dog', 'and', 'a', 'spotted', 'dog', 'are', 'fighting'], ['a', 'black', 'dog', 'and', 'a', 'tri-colored', 'dog', 'playing', 'with', 'each', 'other', 'on', 'the', 'road', '.'], ['a', 'black', 'dog', 'and', 'a', 'white', 'dog', 'with', 'brown', 'spots', 'are', 'staring', 'at', 'each', 'other', 'in', 'the', 'street', '.'], ['two', 'dogs', 'of', 'different', 'breeds', 'looking', 'at', 'each', 'other', 'on', 'the', 'road', '.'], ['two', 'dogs', 'on', 'pavement', 'moving', 'toward', 'each', 'other', '.']]
# Image ID: 1002674143_1b742ab4b8.jpg
# Captions: [['a', 'little', 'girl', 'covered', 'in', 'paint', 'sits', 'in', 'front', 'of', 'a', 'painted', 'rainbow', 'with', 'her', 'hands', 'in', 'a', 'bowl', '.'], ['a', 'little', 'girl', 'is', 'sitting', 'in', 'front', 'of', 'a', 'large', 'painted', 'rainbow', '.'], ['a', 'small', 'girl', 'in', 'the', 'grass', 'plays', 'with', 'fingerpaints', 'in', 'front', 'of', 'a', 'white', 'canvas', 'with', 'a', 'rainbow', 'on', 'it', '.'], ['there', 'is', 'a', 'girl', 'with', 'pigtails', 'sitting', 'in', 'front', 'of', 'a', 'rainbow', 'painting', '.'], ['young', 'girl', 'with', 'pigtails', 'painting', 'outside', 'in', 'the', 'grass', '.']]
# Image ID: 1003163366_44323f5815.jpg
# Captions: [['a', 'man', 'lays', 'on', 'a', 'bench', 'while', 'his', 'dog', 'sits', 'by', 'him', '.'], ['a', 'man', 'lays', 'on', 'the', 'bench', 'to', 'which', 'a', 'white', 'dog', 'is', 'also', 'tied', '.'], ['a', 'man', 'sleeping', 'on', 'a', 'bench', 'outside', 'with', 'a', 'white', 'and', 'black', 'dog', 'sitting', 'next', 'to', 'him', '.'], ['a', 'shirtless', 'man', 'lies', 'on', 'a', 'park', 'bench', 'with', 'his', 'dog', '.'], ['man', 'laying', 'on', 'bench', 'holding', 'leash', 'of', 'dog', 'sitting', 'on', 'ground']]

# %%
# Debug: Print out the hypotheses and references to verify
print(f"Hypotheses: {hypotheses[:3]}")
print(f"References: {references[:3]}")
# Out:
# Hypotheses: []
# References: []

# %%
from nltk.translate.bleu_score import corpus_bleu, SmoothingFunction
from nltk.tokenize import word_tokenize
import glob
import os
from PIL import Image
import torch
from torchvision import transforms  # Import if not already done

# Paths
test_folder = r"C:\Users\User\Documents\FinalYearProject2025\flickr dataset\test"
captions_file = r"C:\Users\User\Documents\FinalYearProject2025\flickr dataset\captions.txt"

# Load reference captions
def load_captions(file_path):
    captions_dict = {}
    with open(file_path, 'r') as f:
        for line in f:
            parts = line.strip().split('\t')
            if len(parts) == 2:
                image_id, caption = parts
                image_id = image_id.split("#")[0]  # Extract image name without #index
                if image_id not in captions_dict:
                    captions_dict[image_id] = []
                captions_dict[image_id].append(word_tokenize(caption.lower()))
    return captions_dict

reference_captions = load_captions(captions_file)

# Transform for test images
test_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# Generate captions for test images
def generate_caption(image_path, model, transform, device):
    image = Image.open(image_path).convert('RGB')
    image_tensor = transform(image).unsqueeze(0).to(device)

    # Extract features and generate caption
    model.eval()
    with torch.no_grad():
        image_features = model.feature_extractor(image_tensor).unsqueeze(1)
        caption = model.generate_caption(image_features)  # Assuming your model has this method
    return word_tokenize(caption.lower())

# Get all test images
test_image_paths = glob.glob(os.path.join(test_folder, '*.jpg'))

# Calculate BLEU scores
hypotheses = []
references = []

for image_path in test_image_paths:
    image_name = os.path.basename(image_path)
    if image_name in reference_captions:
        # Generate caption
        generated_caption = generate_caption(image_path, model, test_transform, device)
        
        # Skip if generated or reference captions are empty
        if generated_caption and reference_captions[image_name]:
            hypotheses.append(generated_caption)
            references.append(reference_captions[image_name])

# Initialize smoothing function
smoothing_function = SmoothingFunction().method1

# Ensure there are valid hypotheses and references
if hypotheses and references:
    # Calculate BLEU scores with different weights and smoothing
    bleu1 = corpus_bleu(references, hypotheses, weights=(1.0, 0, 0, 0), smoothing_function=smoothing_function)  # BLEU-1
    bleu2 = corpus_bleu(references, hypotheses, weights=(0.5, 0.5, 0, 0), smoothing_function=smoothing_function)  # BLEU-2
    bleu3 = corpus_bleu(references, hypotheses, weights=(0.33, 0.33, 0.33, 0), smoothing_function=smoothing_function)  # BLEU-3
    bleu4 = corpus_bleu(references, hypotheses, weights=(0.25, 0.25, 0.25, 0.25), smoothing_function=smoothing_function)  # BLEU-4

    # Print BLEU scores
    print(f"BLEU-1 Score: {bleu1:.4f}")
    print(f"BLEU-2 Score: {bleu2:.4f}")
    print(f"BLEU-3 Score: {bleu3:.4f}")
    print(f"BLEU-4 Score: {bleu4:.4f}")
else:
    print("No valid hypotheses or references to calculate BLEU scores.")
# Out:
# No valid hypotheses or references to calculate BLEU scores.
